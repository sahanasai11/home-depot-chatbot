# %%
import pandas as pd

# %%
df = pd.read_csv('home_depot_data.csv')
df = df.reset_index(drop=True)
df = df.drop(['crawled_at', 'source', 'images', 'sku_id', 'color', 'avg_rating', 'total_reviews', 'in_stock'], axis=1)


df.isnull().sum()
# Out:
# url               0
# name              0
# description       0
# brand             0
# price             0
# currency          0
# breadcrumbs       0
# overview          0
# specifications    0
# dtype: int64

# %%
df = df.dropna()
df.head()
# Out:
#                                                      url  \
# 1      https://www.homedepot.com/p/31-in-x-17-in-Stai...
# 2      https://www.homedepot.com/p/Quoizel-Queenship-...
# 3      https://www.homedepot.com/p/Eagle-Tool-US-1-2-...
# 4      https://www.homedepot.com/p/Safavieh-Kilim-Rus...
# 5      https://www.homedepot.com/p/Unique-Loom-Salzbu...
# ...                                                  ...
# 10831  https://www.homedepot.com/p/Glidden-Speed-Wall...
# 10832  https://www.homedepot.com/p/Toledo-Fine-Locks-...
# 10833  https://www.homedepot.com/p/The-Stupell-Home-D...
# 10834  https://www.homedepot.com/p/BEHR-MARQUEE-1-gal...
# 10835  https://www.homedepot.com/p/Universal-Tubs-Ram...
#
#                                                     name  \
# 1      31 in. x 17 in. Stainless Steel Kitchen Sink B...
# 2          Queenship 2-Light Polished Nickel Wall Sconce
# 3      1/2 in. x 18 in. Flexible Carbide Tip Cable In...
# 4                      Kilim Rust 5 ft. x 8 ft. Area Rug
# 5      Salzburg Itzling Light Blue 4' 0 x 4' 0 Square...
# ...                                                  ...
# 10831  Speed-Wall 1 gal. PPG1105-3 Carmelized Pears F...
# 10832     Antique Bronze Privacy Bed/Bath Door Lever Set
# 10833  30 in. x 40 in. " Fridge Lights are for Midnig...
# 10834  1 gal. #490B-5 Cozumel Satin Enamel Exterior P...
# 10835  Rampart Nova Heated 3.2 ft. Walk-in Whirlpool ...
#
#                                              description  \
# 1      Extend the life of your sink with a bottom gri...
# 2      The Queenship is absolutely dripping with glam...
# 3      Eagle Tools has the Best in Flex. This America...
# 4      Flat-weaving traditions of nomads from the Mid...
# 5      Soft, muted colors like blue, gray and cream. ...
# ...                                                  ...
# 10831  Glidden Speed-Wall professional interior paint...
# 10832  Toledo Fine Locks presents to our customers su...
# 10833  Our stretched canvas is created with only the ...
# 10834  For the ultimate in durability and beauty on v...
# 10835  Walk-In's provide a safe and independent bathi...
#
#                                    brand    price  in_stock currency  \
# 1                              Unbranded    59.00     False      USD
# 2                                Quoizel   232.49      True      USD
# 3                          Eagle Tool US    24.99      True      USD
# 4                               Safavieh   156.33      True      USD
# 5                            Unique Loom    34.69     False      USD
# ...                                  ...      ...       ...      ...
# 10831                            Glidden    12.98     False      USD
# 10832                  Toledo Fine Locks    23.13      True      USD
# 10833  The Stupell Home Decor Collection    68.80      True      USD
# 10834                       BEHR MARQUEE    49.98      True      USD
# 10835                     Universal Tubs  5398.99      True      USD
#
#                                              breadcrumbs  \
# 1      Kitchen, Kitchen Storage & Organization, Kitch...
# 2                                 Lighting, Wall Sconces
# 3      Tools, Power Tool Accessories, Drill Bits, Spe...
# 4                              Flooring, Rugs, Area Rugs
# 5                              Flooring, Rugs, Area Rugs
# ...                                                  ...
# 10831                                Paint, Paint Colors
# 10832  Hardware, Door Hardware, Door Lever Handles, P...
# 10833  Home Decor, Wall Decor, Wall Art, Posters & Ar...
# 10834                                Paint, Paint Colors
# 10835                       Bath, Bathtubs, Walk-in Tubs
#
#                                                 overview  \
# 1      Premium grade T-304 stainless steel, Protects ...
# 2      Durable steel construction is built to last an...
# 3      Made in USA, Carbide tipped, Wire fishing acco...
# 4      100% Wool, No backing, rug pad (sold separatel...
# 5      Pile material is Polypropylene, Action back re...
# ...                                                  ...
# 10831  Built for increased productivity on high-volum...
# 10832  Anti-bumping cylinder, Fits doors from 1-3/8 i...
# 10833  Dimensions: 16 x 1.5 x 20 in., Our stretched c...
# 10834  Satin finish offers a soft, pearl-like appeara...
# 10835  Includes two (2) 60x60 in. 6 in. square tile r...
#
#                                           specifications
# 1      [{'Kitchen Product Type': 'Sink Grids'}, {'Int...
# 2      [{'Fixture Color/Finish': 'Polished Nickel'}, ...
# 3      [{'Self-Feeding': 'No'}, {'Drill Bit Type(s) I...
# 4      [{'Features': 'No Additional Features'}, {'Sty...
# 5      [{'Features': 'Stain Resistant'}, {'Style': 'C...
# ...                                                  ...
# 10831  [{'Minimum Temperature for Use (F)': '50'}, {'...
# 10832  [{'Door Handing': 'Universal'}, {'Interior/Ext...
# 10833  [{'Art Movement': 'Post Impressionism'}, {'Art...
# 10834  [{'Minimum Temperature for Use (F)': '35'}, {'...
# 10835  [{'Exterior bath shape': 'Rectangular'}, {'Dra...
#
# [10352 rows x 10 columns]

# %%
df.to_csv('home_depot_data.csv', index=False)
